# %%
import ee
ee.Authenticate(auth_mode="gcloud")
ee.Initialize(project= 'rmrs-wildfire-treatments')

import geemap
import geopandas as gpd
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
import os
import sys
from datetime import datetime
import math
import sklearn
from sklearn.preprocessing import StandardScaler
from google.cloud import storage
from pathlib import Path

# %%
# !gcloud auth login
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=AxERERkN3O6ksehniPxNhQY4wvm1oP&access_type=offline&code_challenge=c_ilGi3XutT_Vcp0HI6GGgUz_J0HtmADxh8AQRKp5nI&code_challenge_method=S256
#
#
# You are now logged in as [hannah.vandusen@usda.gov].
# Your current project is [rmrs-wildfire-treatments].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID

# %%
# !earthengine -h
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# usage: earthengine [-h] [--ee_config EE_CONFIG]
#                    [--service_account_file SERVICE_ACCOUNT_FILE]
#                    [--project PROJECT_OVERRIDE]
#                    {authenticate,acl,asset,cp,create,ls,alpha,du,mv,model,rm,set_project,task,unset_project,upload,upload_manifest,upload_table_manifest}
#                    ...
#
# Earth Engine Command Line Interface.
#
# options:
#   -h, --help            show this help message and exit
#   --ee_config EE_CONFIG
#                         Path to the earthengine configuration file. Defaults
#                         to "~/.config\earthengine\credentials".
#   --service_account_file SERVICE_ACCOUNT_FILE
#                         Path to a service account credentialsfile. Overrides
#                         any ee_config if specified.
#   --project PROJECT_OVERRIDE
#                         Specifies a Google Cloud Platform Project id to
#                         override the call.
#
# Commands:
#   {authenticate,acl,asset,cp,create,ls,alpha,du,mv,model,rm,set_project,task,unset_project,upload,upload_manifest,upload_table_manifest}
#     authenticate        Prompts the user to authorize access to Earth Engine
#                         via OAuth2.
#     acl                 Prints or updates the access control list of the
#                         specified asset.
#     asset               Prints or updates metadata associated with an Earth
#                         Engine asset.
#     cp                  Creates a new Earth Engine asset as a copy of another
#                         asset.
#     create              Creates assets and folders.
#     ls                  Prints the contents of a folder or collection.
#     alpha               Commands that are part of the v1alpha API.
#     du                  Prints the size and names of all items in a given
#                         folder or collection.
#     mv                  Moves or renames an Earth Engine asset.
#     model               TensorFlow model related commands.
#     rm                  Deletes the specified assets.
#     set_project         Sets the default user project to be used for all API
#                         calls.
#     task                Prints information about or manages long-running
#                         tasks.
#     unset_project       UnSets the default user project to be used for all API
#                         calls.
#     upload              Uploads assets to Earth Engine.
#     upload_manifest     Uploads an image to Earth Engine using the given
#                         manifest file.
#     upload_table_manifest
#                         Uploads a table to Earth Engine using the given
#                         manifest file.

# %%
# !earthengine set_project rmrs-wildfire-treatments
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Successfully saved project id

# %%
# import user-defined settings

# get pathfile of this script
import ipynbname
notebook_path = ipynbname.path()
project_root = notebook_path.parent

import pandas as pd
import ast

# Full local path to user-input csv file
input_path = os.path.join(project_root, "user_input/user_input_general.csv")

# read user-input CSV
df = pd.read_csv(input_path)

# container for created objects from user input csv
user_inputs = {}

for _, row in df.iterrows():
    # Skip rows flagged as R expressions 
    if row["treat_as_R_expression"]: 
        continue
    
    raw = row["value"]

    # Try safe literal parsing; fall back to raw string 
    try: 
        val = ast.literal_eval(raw) 
    except Exception: 
        val = raw 
        
    user_inputs[row["name"]] = val
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
user_inputs["burn_severity_metric"]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 'RDNBR'

# %%
# Google Bucket name 
bucket_name = 'bb-gee-bucket'

# Bucket folder name
folder_name = 'klamath/burn_severity' # to create this folder, must go to https://console.cloud.google.com/storage/browser/bb-gee-bucket/ and add new folder
 
# Local directory to export to
local_directory = user_inputs["processed_data_directory"]
severity_directory = os.path.join(local_directory, "burn_severity/severity_indices")

# Read in fire list 
fire_list = pd.read_csv(local_directory + '/fire_lists/selectedfires.csv')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# FUNCTIONS TO CREATE SPECTRAL INDICES

# Function to apply scaling factors
def apply_scale_factors(image):
    optical_bands = image.select(['SR_B.']).multiply(0.0000275).add(-0.2)
    return image.addBands(optical_bands, None, True)
# Function to apply old scaling factors
def apply_scale_factors2(image):
    optical_bands = image.select(['SR_B.']).multiply(0.001)#.add(-0.2)
    return image.addBands(optical_bands, None, True)

# Function to compute indices for Landsat 8 and 9
def calculate_indices_ls8_9(image):
    nbr = image.normalizedDifference(['SR_B5', 'SR_B7']).toFloat()
    ndvi = image.normalizedDifference(['SR_B5', 'SR_B4']).toFloat()
    ndmi = image.normalizedDifference(['SR_B5', 'SR_B6']).toFloat()

    evi = image.expression(
              '(2.5 * ((B5 - B4) / (B5 + (6 * B4) - (7.5 * B2) + 1)))',
              {'B5': image.select('SR_B5'),
              'B4': image.select('SR_B4'),
              'B2': image.select('SR_B2'),
              }).toFloat()
    mirbi = image.expression(
        '((10 * SR_B6) - (9.8 * SR_B7) + 2)',
        {'SR_B6': image.select('SR_B6'),
         'SR_B7': image.select('SR_B7')}
    ).toFloat()
    qa = image.select(['QA_PIXEL'])
    return nbr.addBands([ndvi, ndmi, evi, mirbi, qa]).select([0, 1, 2, 3, 4, 5], ['nbr', 'ndvi', 'ndmi', 'evi', 'mirbi', 'QA_PIXEL']).copyProperties(image, ['system:time_start'])

# Function to compute indices for Landsat 4, 5, and 7
def calculate_indices_ls4_7(image):
    nbr = image.normalizedDifference(['SR_B4', 'SR_B7']).toFloat()
    ndvi = image.normalizedDifference(['SR_B4', 'SR_B3']).toFloat()
    ndmi = image.normalizedDifference(['SR_B4', 'SR_B5']).toFloat()
    evi = image.expression(
        '2.5 * ((SR_B4 - SR_B3) / (SR_B4 + 6 * SR_B3 - 7.5 * SR_B1 + 1))',
        {'SR_B4': image.select('SR_B4'),
         'SR_B3': image.select('SR_B3'),
         'SR_B1': image.select('SR_B1')}
    ).toFloat()
    mirbi = image.expression(
        '((10 * SR_B5) - (9.8 * SR_B7) + 2)',
        {'SR_B5': image.select('SR_B5'),
         'SR_B7': image.select('SR_B7')}
    ).toFloat()
    qa = image.select(['QA_PIXEL'])
    return nbr.addBands([ndvi, ndmi, evi, mirbi, qa]).select([0, 1, 2, 3, 4, 5], ['nbr', 'ndvi', 'ndmi', 'evi', 'mirbi', 'QA_PIXEL']).copyProperties(image, ['system:time_start'])


# FUNCTION TO MASK CLOUD, WATER, SNOW, ETC.
def lsCfmask(image):
    # Bits 3,4,5,7: cloud,cloud-shadow,snow,water respectively.
    clouds_bit_mask = (1 << 3)
    cloud_shadow_bit_mask = (1 << 4)
    snow_bit_mask = (1 << 5)
    water_bit_mask = (1 << 7)
    # Get the pixel QA band.
    qa = image.select('QA_PIXEL')
    
    # Flags should be set to zero, indicating clear conditions.
    clear = qa.bitwiseAnd(clouds_bit_mask).eq(0).And(qa.bitwiseAnd(cloud_shadow_bit_mask).eq(0)).And(qa.bitwiseAnd(snow_bit_mask).eq(0)).And(qa.bitwiseAnd(water_bit_mask).eq(0))
    return image.updateMask(clear).select([0, 1, 2, 3, 4]).copyProperties(image, ["system:time_start"])


# Main Function for per fire processing
def process_fire(fire_id, fire_pd, local_directory, indicie_ls, mtbs_perim = False ): # true/false for using mtbs or local shapefile
    # 0) FIRE ID ---------------------------------------------------------------------------------
    fire = fire_id
    
    # 1) INITIALIZE FIRE DATAFRAME FOR PROCESSING -------------------------------------------------
    # Add years
    fire_pd['Year'] = pd.to_datetime(fire_pd['Ignition']).dt.year
    
    # Date Manipulation of Dataframe
    # Define fire season for AOI
    # Parks et al 2014 used startday = 91 and endday = 181 for fires in Arizona, New Mexico, and Utah.
    # And startday = 152 and endday = 273 for fires in California, Montana, Washington, and Wyoming.
    # For Klamath-Trinity, I defined startday = 152 and endday = 273, for other landscapes we can add this as a function input
    start_day = 152
    end_day = 273
    
    fire_pd['start_day'] = start_day
    fire_pd['end_day'] = end_day

    # All available bands for export
    bandList = indicie_ls
    #bandList = ['dnbr', 'rbr', 'rdnbr', 'dndvi', 'devi', 'dndmi', 'dmirbi', 'post_nbr', 'post_mirbi', 'CBI', 'CBI_bc']

    # 2) RANDOM FOREST SPECIFICATIONS------------------------------------------------------------
    # Bands for the random forest classification
    rf_bands = ['def', 'lat', 'rbr', 'dmirbi', 'dndvi', 'post_mirbi']
    
    # Load training data for Random Forest classification
    cbi = ee.FeatureCollection("users/grumpyunclesean/CBI_predictions/data_for_ee_model")
    
    # Load climatic water deficit variable (def) for random forest classification
    def_img = ee.Image("users/grumpyunclesean/CBI_predictions/def").rename('def').int()
    
    # Create latitude image for random forest classification
    lat = ee.Image.pixelLonLat().select('latitude').rename('lat').round().toInt()
    
    # Parameters for random forest classification
    nrow_training_fold = cbi.size()  # number of training observations
    minLeafPopulation = nrow_training_fold.divide(75).divide(6).round()
    
    # Random forest classifier
    fsev_classifier = ee.Classifier.smileRandomForest(
        numberOfTrees = 500,
        minLeafPopulation = minLeafPopulation,
        seed = 123).train(cbi,'CBI',rf_bands).setOutputMode('REGRESSION')

    #  3) GET LANDSAT COLLECTIONS --------------------------------     
    # Landsat 5, 7, 8 and 9 Surface Reflectance (Level 2) Tier 1 Collection 2 
    
    # Get Landsat collections
    ls_collections = {
        'ls9': ee.ImageCollection('LANDSAT/LC09/C02/T1_L2'),
        'ls8': ee.ImageCollection('LANDSAT/LC08/C02/T1_L2'),
        'ls7': ee.ImageCollection('LANDSAT/LE07/C02/T1_L2'),
        'ls5': ee.ImageCollection('LANDSAT/LT05/C02/T1_L2'),
        'ls4': ee.ImageCollection('LANDSAT/LT04/C02/T1_L2')
    }

    # Create water mask from Hansen's Global Forest Change to use in processing function
    water_mask = ee.Image('UMD/hansen/global_forest_change_2023_v1_11').select(['datamask']).eq(1)
    
    # Apply the functions to the collections
    ls_collections = {key: col.map(apply_scale_factors)
                      .map(calculate_indices_ls8_9 if key in ['ls8', 'ls9'] else calculate_indices_ls4_7)
                      .map(lsCfmask) for key, col in ls_collections.items()}
    
    # Merge Landsat Collections 
    ls_col = ee.ImageCollection(ls_collections['ls9']
                                .merge(ls_collections['ls8'])
                                .merge(ls_collections['ls7'])
                                .merge(ls_collections['ls5'])
                                .merge(ls_collections['ls4']))

    # 4) CALCULATE BURN SEVERITY ON A PER FIRE BASIS -----------------------------------------  
    if mtbs_perim == True:
    # indent lines below  
        mtbs_perims = ee.FeatureCollection('USFS/GTAC/MTBS/burned_area_boundaries/v1')
        fire_bounds = ee.Feature(mtbs_perims.filterMetadata('Event_ID', 'equals', fire).first())
        fire_bounds = fire_bounds.geometry().buffer(1000)
    else:
        merged_perim_gdf = gpd.read_file(local_directory +'/fire_perimeters/merged/' + fire + '_Extent.shp')
        fire_bounds = geemap.geopandas_to_ee(merged_perim_gdf)
        fire_bounds = fire_bounds.first().geometry().buffer(1000)
    
    fire_year = ee.Date.parse('YYYY', str(fire_pd[fire_pd['MTBS_ID'] == fire]['Year'].iloc[0]))
    start_day = ee.Number.parse(str(fire_pd[fire_pd['MTBS_ID'] == fire]['start_day'].iloc[0]))
    end_day = ee.Number.parse(str(fire_pd[fire_pd['MTBS_ID'] == fire]['end_day'].iloc[0]))


    # Pre-Imagery
    pre_fire_year = fire_year.advance(-1, 'year')
    # Check if imagery is available for 1 year pre fire; if so, get means across pixels; otherwise, output imagery will be masked
    pre_fire_indices = ee.Algorithms.If(
        ls_col.filterBounds(fire_bounds).filterDate(pre_fire_year, fire_year).filter(ee.Filter.dayOfYear(start_day, end_day)).size(),
        ls_col.filterBounds(fire_bounds).filterDate(pre_fire_year, fire_year).filter(ee.Filter.dayOfYear(start_day, end_day)).mean().select([0,1,2,3,4], ['pre_nbr','pre_ndvi', 'pre_ndmi', 'pre_evi','pre_mirbi']),
        ee.Image.cat(ee.Image(), ee.Image(), ee.Image(), ee.Image(), ee.Image()).rename(['pre_nbr','pre_ndvi', 'pre_ndmi', 'pre_evi','pre_mirbi'])
    )
    
    # If any pixels within fire have only one 'scene' or less, add additional year backward to fill in behind
    pre_fire_year2 = fire_year.advance(-2, 'year')
    pre_fire_indices2 = ee.Algorithms.If(
        ls_col.filterBounds(fire_bounds).filterDate(pre_fire_year2, fire_year).filter(ee.Filter.dayOfYear(start_day, end_day)).size(),
        ls_col.filterBounds(fire_bounds).filterDate(pre_fire_year2, fire_year).filter(ee.Filter.dayOfYear(start_day, end_day)).mean().select([0,1,2,3,4], ['pre_nbr','pre_ndvi', 'pre_ndmi', 'pre_evi','pre_mirbi']),
        ee.Image.cat(ee.Image(), ee.Image(), ee.Image(), ee.Image(), ee.Image()).rename(['pre_nbr','pre_ndvi', 'pre_ndmi', 'pre_evi','pre_mirbi'])
    )
    
    pre_filled = ee.Image(pre_fire_indices).unmask(pre_fire_indices2)
    
    # Post-Imagery
    post_fire_year = fire_year.advance(1, 'year')
    post_fire_year2 = fire_year.advance(2, 'year')
    # Check if imagery is available for 1 year post fire; if so, get means across pixels; otherwise, output imagery will be masked
    post_fire_indices = ee.Algorithms.If(
        ls_col.filterBounds(fire_bounds).filterDate(post_fire_year, post_fire_year2).filter(ee.Filter.dayOfYear(start_day, end_day)).size(),
        ls_col.filterBounds(fire_bounds).filterDate(post_fire_year, post_fire_year2).filter(ee.Filter.dayOfYear(start_day, end_day)).mean().select([0,1,2,3,4], ['post_nbr','post_ndvi', 'post_ndmi', 'post_evi','post_mirbi']),
        ee.Image.cat(ee.Image(), ee.Image(), ee.Image(), ee.Image(), ee.Image()).rename(['post_nbr','post_ndvi', 'post_ndmi', 'post_evi','post_mirbi'])
    )
    
    post_fire_year3 = fire_year.advance(3, 'year')
    # If any pixels within fire have only one 'scene' or less, add additional year forward to fill in behind
    post_fire_indices2 = ee.Algorithms.If(
        ls_col.filterBounds(fire_bounds).filterDate(post_fire_year, post_fire_year3).filter(ee.Filter.dayOfYear(start_day, end_day)).size(),
        ls_col.filterBounds(fire_bounds).filterDate(post_fire_year, post_fire_year3).filter(ee.Filter.dayOfYear(start_day, end_day)).mean().select([0,1,2,3,4], ['post_nbr','post_ndvi', 'post_ndmi', 'post_evi','post_mirbi']),
        ee.Image.cat(ee.Image(), ee.Image(), ee.Image(), ee.Image(), ee.Image()).rename(['post_nbr','post_ndvi', 'post_ndmi', 'post_evi','post_mirbi'])
    )
    
    post_filled = ee.Image(post_fire_indices).unmask(post_fire_indices2)
    fireIndices = pre_filled.addBands(post_filled) #Here
    
    # Calculate dNBR
    burnIndices = fireIndices.expression(
        "(b('pre_nbr') - b('post_nbr')) * 1000"
    ).rename('dnbr').toInt().addBands(fireIndices)
    
    # Calculate RBR
    burnIndices2 = burnIndices.expression(
        "b('dnbr') / (b('pre_nbr') + 1.001)"
    ).rename('rbr').toInt().addBands(burnIndices)
    
    # Calculate RdNBR
    burnIndices3 = burnIndices2.expression(
        "abs(b('pre_nbr')) < 0.001 ? 0.001 : b('pre_nbr')"
    ).abs().sqrt().rename('pre_nbr2').toFloat().addBands(burnIndices2)
   
    burnIndices4 = burnIndices3.expression(
        "b('dnbr') / b('pre_nbr2')"
    ).rename('rdnbr').toInt().addBands(burnIndices3)
    
    # Calculate basal area percent change (Miller 2009a)
    burnIndices45 = burnIndices4.expression(
        "100 * pow(sin((b('rdnbr') - 166.5) / 389), 2)"
    ).rename('per_BA').toInt().addBands(burnIndices4)
    
    # Calculate dNDVI
    burnIndices5 = burnIndices45.expression(
        "(b('pre_ndvi') - b('post_ndvi')) * 1000"
    ).rename('dndvi').toInt().addBands(burnIndices45)
    
    # Calculate dEVI
    burnIndices6 = burnIndices5.expression(
        "(b('pre_evi') - b('post_evi')) * 1000"
    ).rename('devi').toInt().addBands(burnIndices5)
    
    # Calculate dNDMI
    burnIndices7 = burnIndices6.expression(
        "(b('pre_ndmi') - b('post_ndmi')) * 1000"
    ).rename('dndmi').toInt().addBands(burnIndices6)
    
    # Calculate dMIRBI
    burnIndices8 = burnIndices7.expression(
        "(b('pre_mirbi') - b('post_mirbi')) * 1000"
    ).rename('dmirbi').toInt().addBands(burnIndices7)
    
    
    # Multiply post_mirbi band by 1000 to put it on the same scale as CBI plot extractions
    post_mirbi_1000 = burnIndices8.select("post_mirbi").multiply(1000).toInt()
    burnIndices8 = burnIndices8.addBands(post_mirbi_1000, None, True)  # None to copy all bands; True to overwrite original post_mirbi
    
    # Get a list of all metadata properties.
    properties = burnIndices8.propertyNames()
    
    # Add in climatic water deficit variable, i.e. def
    burnIndices9 = burnIndices8.addBands(def_img)
    
    # Add in latitude
    burnIndices10 = burnIndices9.addBands(lat)
    
    # Classify the image with the same bands used to train the Random Forest classifier
    cbi_rf = burnIndices10.select(rf_bands).classify(fsev_classifier).rename('CBI').toFloat().multiply(10**2).floor().divide(10**2)
    
    burnIndices11 = cbi_rf.addBands(burnIndices10)
    
    # Create bias corrected CBI
    def bias_correct(bandName):
        cbi_lo = bandName.expression("((b('CBI') - 1.5) * 1.3)  + 1.5")
        cbi_hi = bandName.expression("((b('CBI') - 1.5) * 1.175) + 1.5")
        cbi_mg = bandName.where(bandName.lte(1.5), cbi_lo).where(bandName.gt(1.5), cbi_hi)
        return cbi_mg.where(cbi_mg.lt(0), 0).where(cbi_mg.gt(3), 3).multiply(10**2).floor().divide(10**2).rename('CBI_bc')
    
    validMask = pre_filled.select('pre_nbr').add(10).add(post_filled.select('post_nbr')).add(10)  # Adding 10 ensures resulting image doesn't have 0 values that would become masked in final output bands
    mask = water_mask.updateMask(validMask)
    burnIndices12 = bias_correct(burnIndices11.select('CBI')).addBands(burnIndices11)
    burnIndices12 = burnIndices12.updateMask(mask).clip(fire_bounds).select(bandList, bandList)

    return burnIndices12.set({'fireID': fire, 'fireYear': fire_year})
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Fires of interest
fireIDs = fire_list['MTBS_ID'].values.tolist()

for fireID in fireIDs:
    
    this_fire = fireID

    # Load in merged perimeters
    merged_perim_gdf = gpd.read_file(local_directory +'/fire_perimeters/merged/' + fireID + '_Extent.shp')
    fire_bounds = geemap.geopandas_to_ee(merged_perim_gdf)
    fire_bounds = fire_bounds.first().geometry().buffer(1000)

    # indicies of interest
    indicies = [user_inputs["burn_severity_metric"].lower()]
    
    this_sev = process_fire(this_fire, fire_list, local_directory, indicies, mtbs_perim = False )  
    this_sev = this_sev.select(indicies[0])
    nm = this_fire + '_' + indicies[0]
    # print(nm)

    task = ee.batch.Export.image.toCloudStorage(
        image=this_sev,
        description=nm,
        bucket=bucket_name,
        fileNamePrefix=f"{folder_name}/{nm}",
        region=fire_bounds,
        scale=30,
        maxPixels=5e8
    )
    task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# download rasters to computer
storage_client = storage.Client()
bucket = storage_client.bucket(bucket_name)

# Collect expected filenames from earlier
expected_filenames = {
    f"{folder_name}/{os.path.splitext(os.path.basename(fireID))[0].split('_')[0]}_{user_inputs['burn_severity_metric'].lower()}.tif"
    for fireID in fireIDs
}


blobs = list(bucket.list_blobs(prefix=folder_name))

for blob in blobs:
    if blob.name in expected_filenames:
        local_path = os.path.join(severity_directory, os.path.basename(blob.name))
        os.makedirs(os.path.dirname(local_path), exist_ok=True)
        print(f"Downloading {blob.name} to {local_path}")
        blob.download_to_filename(local_path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'klamath/burn_severity/CA4145912232920210625_rdnbr.tif', 'klamath/burn_severity/CA4173712105820200723_rdnbr.tif', 'klamath/burn_severity/CA4174812105620190905_rdnbr.tif', 'klamath/burn_severity/CA4185812335420200908_rdnbr.tif', 'klamath/burn_severity/CA4038712317320150730_rdnbr.tif', 'klamath/burn_severity/CA4035712344220150731_rdnbr.tif', 'klamath/burn_severity/CA4185212099120170726_rdnbr.tif', 'klamath/burn_severity/CA4179612337420140814_rdnbr.tif', 'klamath/burn_severity/CA4194712334920170808_rdnbr.tif', 'klamath/burn_severity/OR4254212214420170810_rdnbr.tif', 'klamath/burn_severity/CA4045612355620150806_rdnbr.tif', 'klamath/burn_severity/CA4121212284720200914_rdnbr.tif', 'klamath/burn_severity/OR4228612140420210619_rdnbr.tif', 'klamath/burn_severity/OR4261612142120210706_rdnbr.tif', 'klamath/burn_severity/CA4132412320120210731_rdnbr.tif', 'klamath/burn_severity/CA4049212319820150803_rdnbr.tif', 'klamath/burn_severity/CA4178612347520170812_rdnbr.tif', 'klamath/burn_severity/CA4156412340420210801_rdnbr.tif', 'klamath/burn_severity/CA4114112280520140802_rdnbr.tif', 'klamath/burn_severity/CA4145212338020170811_rdnbr.tif', 'klamath/burn_severity/CA4075212333720210731_rdnbr.tif', 'klamath/burn_severity/CA4143512316220170626_rdnbr.tif', 'klamath/burn_severity/CA4152312316420140813_rdnbr.tif', 'klamath/burn_severity/OR4211012080120120806_rdnbr.tif', 'klamath/burn_severity/CA4195612355120180715_rdnbr.tif', 'klamath/burn_severity/CA4159712349220170725_rdnbr.tif', 'klamath/burn_severity/CA4046512305420150731_rdnbr.tif', 'klamath/burn_severity/OR4279812231820170725_rdnbr.tif', 'klamath/burn_severity/CA4091612363420210829_rdnbr.tif', 'klamath/burn_severity/CA4126812300220140731_rdnbr.tif', 'klamath/burn_severity/CA4069112352420150610_rdnbr.tif', 'klamath/burn_severity/CA4064212358620150731_rdnbr.tif', 'klamath/burn_severity/CA4035812356120150806_rdnbr.tif', 'klamath/burn_severity/CA4054612309020120905_rdnbr.tif', 'klamath/burn_severity/CA4192412288020140730_rdnbr.tif', 'klamath/burn_severity/CA4068012335620150731_rdnbr.tif', 'klamath/burn_severity/CA4166512205420210628_rdnbr.tif', 'klamath/burn_severity/CA4060412308120150731_rdnbr.tif', 'klamath/burn_severity/CA4185312311520160828_rdnbr.tif', 'klamath/burn_severity/CA4188812325320120805_rdnbr.tif', 'klamath/burn_severity/CA4168212212720140731_rdnbr.tif', 'klamath/burn_severity/CA4094312242720180905_rdnbr.tif', 'klamath/burn_severity/CA4130012313520130731_rdnbr.tif', 'klamath/burn_severity/CA4035012303620210730_rdnbr.tif', 'klamath/burn_severity/CA4118512343320200728_rdnbr.tif', 'klamath/burn_severity/CA4146912375220150801_rdnbr.tif', 'klamath/burn_severity/CA4180012381520150801_rdnbr.tif', 'klamath/burn_severity/CA4091312343720150731_rdnbr.tif', 'klamath/burn_severity/CA4077112312420170831_rdnbr.tif', 'klamath/burn_severity/CA4022812303620170913_rdnbr.tif', 'klamath/burn_severity/CA3966012280920200817_rdnbr.tif', 'klamath/burn_severity/CA4162312355820160607_rdnbr.tif', 'klamath/burn_severity/CA4103512348820130810_rdnbr.tif', 'klamath/burn_severity/CA4133312337620130731_rdnbr.tif', 'klamath/burn_severity/OR4231312098120170731_rdnbr.tif', 'klamath/burn_severity/CA4018412336320170808_rdnbr.tif', 'klamath/burn_severity/OR4265012082720180815_rdnbr.tif', 'klamath/burn_severity/OR4307312203920180715_rdnbr.tif', 'klamath/burn_severity/CA4065012263020180723_rdnbr.tif', 'klamath/burn_severity/OR4265312186920200908_rdnbr.tif', 'klamath/burn_severity/OR4253212123820210418_rdnbr.tif', 'klamath/burn_severity/CA4172612124320190728_rdnbr.tif', 'klamath/burn_severity/CA4169912147720200722_rdnbr.tif', 'klamath/burn_severity/CA4079212335020120711_rdnbr.tif', 'klamath/burn_severity/CA4150012192920210801_rdnbr.tif', 'klamath/burn_severity/CA4034312338320150731_rdnbr.tif', 'klamath/burn_severity/CA4198012316420170811_rdnbr.tif', 'klamath/burn_severity/CA4114212301620210731_rdnbr.tif', 'klamath/burn_severity/OR4278712097620210712_rdnbr.tif', 'klamath/burn_severity/CA4155612377620150802_rdnbr.tif'}
# Downloading klamath/burn_severity/CA3966012280920200817_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA3966012280920200817_rdnbr.tif
# Downloading klamath/burn_severity/CA4018412336320170808_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4018412336320170808_rdnbr.tif
# Downloading klamath/burn_severity/CA4022812303620170913_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4022812303620170913_rdnbr.tif
# Downloading klamath/burn_severity/CA4034312338320150731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4034312338320150731_rdnbr.tif
# Downloading klamath/burn_severity/CA4035012303620210730_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4035012303620210730_rdnbr.tif
# Downloading klamath/burn_severity/CA4035712344220150731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4035712344220150731_rdnbr.tif
# Downloading klamath/burn_severity/CA4035812356120150806_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4035812356120150806_rdnbr.tif
# Downloading klamath/burn_severity/CA4038712317320150730_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4038712317320150730_rdnbr.tif
# Downloading klamath/burn_severity/CA4045612355620150806_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4045612355620150806_rdnbr.tif
# Downloading klamath/burn_severity/CA4046512305420150731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4046512305420150731_rdnbr.tif
# Downloading klamath/burn_severity/CA4049212319820150803_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4049212319820150803_rdnbr.tif
# Downloading klamath/burn_severity/CA4054612309020120905_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4054612309020120905_rdnbr.tif
# Downloading klamath/burn_severity/CA4060412308120150731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4060412308120150731_rdnbr.tif
# Downloading klamath/burn_severity/CA4064212358620150731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4064212358620150731_rdnbr.tif
# Downloading klamath/burn_severity/CA4065012263020180723_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4065012263020180723_rdnbr.tif
# Downloading klamath/burn_severity/CA4068012335620150731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4068012335620150731_rdnbr.tif
# Downloading klamath/burn_severity/CA4069112352420150610_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4069112352420150610_rdnbr.tif
# Downloading klamath/burn_severity/CA4075212333720210731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4075212333720210731_rdnbr.tif
# Downloading klamath/burn_severity/CA4077112312420170831_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4077112312420170831_rdnbr.tif
# Downloading klamath/burn_severity/CA4079212335020120711_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4079212335020120711_rdnbr.tif
# Downloading klamath/burn_severity/CA4091312343720150731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4091312343720150731_rdnbr.tif
# Downloading klamath/burn_severity/CA4091612363420210829_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4091612363420210829_rdnbr.tif
# Downloading klamath/burn_severity/CA4094312242720180905_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4094312242720180905_rdnbr.tif
# Downloading klamath/burn_severity/CA4103512348820130810_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4103512348820130810_rdnbr.tif
# Downloading klamath/burn_severity/CA4114112280520140802_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4114112280520140802_rdnbr.tif
# Downloading klamath/burn_severity/CA4114212301620210731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4114212301620210731_rdnbr.tif
# Downloading klamath/burn_severity/CA4118512343320200728_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4118512343320200728_rdnbr.tif
# Downloading klamath/burn_severity/CA4121212284720200914_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4121212284720200914_rdnbr.tif
# Downloading klamath/burn_severity/CA4126812300220140731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4126812300220140731_rdnbr.tif
# Downloading klamath/burn_severity/CA4130012313520130731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4130012313520130731_rdnbr.tif
# Downloading klamath/burn_severity/CA4132412320120210731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4132412320120210731_rdnbr.tif
# Downloading klamath/burn_severity/CA4133312337620130731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4133312337620130731_rdnbr.tif
# Downloading klamath/burn_severity/CA4143512316220170626_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4143512316220170626_rdnbr.tif
# Downloading klamath/burn_severity/CA4145212338020170811_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4145212338020170811_rdnbr.tif
# Downloading klamath/burn_severity/CA4145912232920210625_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4145912232920210625_rdnbr.tif
# Downloading klamath/burn_severity/CA4146912375220150801_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4146912375220150801_rdnbr.tif
# Downloading klamath/burn_severity/CA4150012192920210801_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4150012192920210801_rdnbr.tif
# Downloading klamath/burn_severity/CA4152312316420140813_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4152312316420140813_rdnbr.tif
# Downloading klamath/burn_severity/CA4155612377620150802_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4155612377620150802_rdnbr.tif
# Downloading klamath/burn_severity/CA4156412340420210801_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4156412340420210801_rdnbr.tif
# Downloading klamath/burn_severity/CA4159712349220170725_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4159712349220170725_rdnbr.tif
# Downloading klamath/burn_severity/CA4162312355820160607_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4162312355820160607_rdnbr.tif
# Downloading klamath/burn_severity/CA4166512205420210628_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4166512205420210628_rdnbr.tif
# Downloading klamath/burn_severity/CA4168212212720140731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4168212212720140731_rdnbr.tif
# Downloading klamath/burn_severity/CA4169912147720200722_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4169912147720200722_rdnbr.tif
# Downloading klamath/burn_severity/CA4172612124320190728_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4172612124320190728_rdnbr.tif
# Downloading klamath/burn_severity/CA4173712105820200723_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4173712105820200723_rdnbr.tif
# Downloading klamath/burn_severity/CA4174812105620190905_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4174812105620190905_rdnbr.tif
# Downloading klamath/burn_severity/CA4178612347520170812_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4178612347520170812_rdnbr.tif
# Downloading klamath/burn_severity/CA4179612337420140814_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4179612337420140814_rdnbr.tif
# Downloading klamath/burn_severity/CA4180012381520150801_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4180012381520150801_rdnbr.tif
# Downloading klamath/burn_severity/CA4185212099120170726_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4185212099120170726_rdnbr.tif
# Downloading klamath/burn_severity/CA4185312311520160828_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4185312311520160828_rdnbr.tif
# Downloading klamath/burn_severity/CA4185812335420200908_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4185812335420200908_rdnbr.tif
# Downloading klamath/burn_severity/CA4188812325320120805_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4188812325320120805_rdnbr.tif
# Downloading klamath/burn_severity/CA4192412288020140730_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4192412288020140730_rdnbr.tif
# Downloading klamath/burn_severity/CA4194712334920170808_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4194712334920170808_rdnbr.tif
# Downloading klamath/burn_severity/CA4195612355120180715_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4195612355120180715_rdnbr.tif
# Downloading klamath/burn_severity/CA4198012316420170811_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\CA4198012316420170811_rdnbr.tif
# Downloading klamath/burn_severity/OR4211012080120120806_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\OR4211012080120120806_rdnbr.tif
# Downloading klamath/burn_severity/OR4228612140420210619_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\OR4228612140420210619_rdnbr.tif
# Downloading klamath/burn_severity/OR4231312098120170731_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\OR4231312098120170731_rdnbr.tif
# Downloading klamath/burn_severity/OR4253212123820210418_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\OR4253212123820210418_rdnbr.tif
# Downloading klamath/burn_severity/OR4254212214420170810_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\OR4254212214420170810_rdnbr.tif
# Downloading klamath/burn_severity/OR4261612142120210706_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\OR4261612142120210706_rdnbr.tif
# Downloading klamath/burn_severity/OR4265012082720180815_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\OR4265012082720180815_rdnbr.tif
# Downloading klamath/burn_severity/OR4265312186920200908_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\OR4265312186920200908_rdnbr.tif
# Downloading klamath/burn_severity/OR4278712097620210712_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\OR4278712097620210712_rdnbr.tif
# Downloading klamath/burn_severity/OR4279812231820170725_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\OR4279812231820170725_rdnbr.tif
# Downloading klamath/burn_severity/OR4307312203920180715_rdnbr.tif to C:/Users/HannahVanDusen/Box/External Wildfire Treatment Outcomes/klamath/data/klamath\burn_severity/severity_indicies\OR4307312203920180715_rdnbr.tif
